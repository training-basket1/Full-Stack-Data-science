# %% [markdown]
# ## Author - Prem kumar bharti
#
# ### Seaborn

# %% [markdown]
# * Seaborn is a python library for data visualization build on top of the matplotlib python library

# %% [markdown]
# * Seaborn helps you explore and understand your data. Its plotting functions operate on dataframes and arrays containing whole datasets and internally perform the necessary semantic mapping and statistical aggregation to produce informative plots. Its dataset-oriented, declarative API lets you focus on what the different elements of your plots mean, rather than on the details of how to draw them.

# %%
# importing libraries
import seaborn as sns
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Lineplot

# %%
days = list(range(1, 16))
temperature = [36.5 , 38 , 37 , 39 , 40 , 43 , 45 , 46.4 , 47 , 48 , 49 , 46.5 , 49 , 45 , 43 ]

# %%
sns.lineplot(days ,temperature)
# Out:
# C:\Users\Prem\Anaconda3\envs\flight\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:>

# %%
df = pd.DataFrame({"days" : days , "temperature" : temperature})

# %%
df
# Out:
#     days  temperature
# 0      1         36.5
# 1      2         38.0
# 2      3         37.0
# 3      4         39.0
# 4      5         40.0
# 5      6         43.0
# 6      7         45.0
# 7      8         46.4
# 8      9         47.0
# 9     10         48.0
# 10    11         49.0
# 11    12         46.5
# 12    13         49.0
# 13    14         45.0
# 14    15         43.0

# %%
sns.lineplot(x = "days" , y = "temperature" , data = df)
plt.show()

# %% [markdown]
# ## Histogram

# %%
df_tip = sns.load_dataset("tips")

# %%
df_tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
x = df_tip["total_bill"]
sns.distplot(x  , color = "red" , axlabel = "total bill"  ,    
             label = "totall_bill")
plt.legend(loc = 0)
plt.title("Histogram", fontsize = 18 , color = "blue")
plt.show()
# Out:
# C:\Users\Prem\Anaconda3\envs\flight\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df_tip["total_bill"])
# Out:
# C:\Users\Prem\Anaconda3\envs\flight\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ## Scatter plot

# %%
df_1 = sns.load_dataset("titanic")
df_1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#plt.figure(figsize = (20 , 20))
sns.scatterplot(x = "age" , y = "fare" , data = df_1 , hue = "sex" , style = "survived" ,alpha = 0.8 , sizes=100)
# Out:
# <AxesSubplot:xlabel='age', ylabel='fare'>

# %% [markdown]
# ## heatmap

# %%
df_tip.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df_tip.corr() , annot=True, cmap = "PuBuGn_r")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## jointplot

# %%
sns.jointplot(x='tip',y='total_bill',data=df_tip,kind='hex')

# %%
sns.jointplot(x='tip',y='total_bill',data=df_tip,kind='reg')

# %%
sns.pairplot(df_tip,hue='sex') ## multivariate analysis

# %% [markdown]
# ## Count plot

# %%
sns.countplot(x='sex', data=df_1 )
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
df_1["sex"].value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %% [markdown]
# ## Bar plot

# %%
df_tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(x='sex', y='total_bill', data = df_tip )
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ## boxplot

# %%
sns.boxplot('smoker','total_bill', data=df_tip)
# Out:
# C:\Users\Prem\Anaconda3\envs\flight\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='smoker', ylabel='total_bill'>
